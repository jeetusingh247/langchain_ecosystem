# %% [markdown]
# #### Model Integration with OpenAI, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("gpt-4.1")
model
# Out:
# ChatOpenAI(profile={'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000001CEA2FAECF0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001CEA2FAF770>, root_client=<openai.OpenAI object at 0x000001CEA2FAC2F0>, root_async_client=<openai.AsyncOpenAI object at 0x000001CEA2FAF4D0>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %%
## invoke the model here
response=model.invoke("Hello how are you?")
response

# %% [markdown]
# #### Google Gemini Model

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("Create an image of Parrot")
response
# Out:
# AIMessage(content='Okay, I can help you create an image of a parrot! To make sure I generate the best possible image for you, I need a little more information. Please tell me:\n\n**1. What kind of parrot would you like?**\n\n*   **Specific Species:** Do you have a particular type in mind? (e.g., Macaw, African Grey, Cockatiel, Amazon Parrot, Budgie/Parakeet, Conure, Eclectus, Lorikeet, etc.)\n*   **General Appearance:** If you don\'t have a specific species, what general look are you going for? (e.g., very colorful, mostly green, large, small, etc.)\n\n**2. What is the parrot doing?**\n\n*   **Perched:** Sitting on a branch, a stand, or something else?\n*   **Flying:** In the air?\n*   **Interacting:** Eating a fruit, looking at the viewer, preening?\n*   **Just posing:** A classic portrait?\n\n**3. What is the setting or background?**\n\n*   **Natural:** Jungle, rainforest, tropical foliage, a single large leaf?\n*   **Simple/Studio:** A plain color background, a gradient?\n*   **Indoor:** On a perch inside a room?\n\n**4. What is the overall mood or style?**\n\n*   **Realistic/Photorealistic:** Like a photograph.\n*   **Artistic/Illustrative:** More like a painting or drawing.\n*   **Vibrant and cheerful:** Bright colors, happy feel.\n*   **Majestic/Elegant:** More subdued colors, regal pose.\n\n**Once you give me some of these details, I can generate a prompt for an image generator!**\n\n**In the meantime, here\'s a general prompt that would create a common, colorful parrot:**\n\n"A vibrant, photorealistic image of a colorful parrot perched on a branch, with lush green tropical foliage in the background. The parrot has bright blue, yellow, and red feathers. The lighting is soft and natural."\n\nLooking forward to your specifics!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bb761-d23c-7652-9e7e-abe12804a1c6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 443, 'total_tokens': 449, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# #### GROQ Integration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

model = init_chat_model("")
response = model.invoke("Why do parrots talk?")
response
